# %%
# Run each cell in order in Google Colab

# ============ CELL 1: Setup ============
# !pip install ultralytics
from google.colab import drive
drive.mount('/content/drive')

# ============ CELL 2: Unzip from Google Drive ============
# !unzip -q "/content/drive/MyDrive/Bookshelf recognition.v1i.yolov8.zip" -d /content/dataset

# Check what's inside
# !ls /content/dataset

# ============ CELL 3: Train ============
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data='/content/dataset/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    project='/content/drive/MyDrive/yolo_training',
    name='spine_detector',
    patience=20
)

# ============ CELL 4: Download trained model ============
from google.colab import files
files.download('/content/drive/MyDrive/yolo_training/spine_detector/weights/best.pt')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.5 MB/s eta 0:00:00
# ...
# Mounted at /content/drive
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
